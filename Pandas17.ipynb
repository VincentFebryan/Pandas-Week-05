# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.4
# 1.20.3

# %%
n_rows = 365 * 24
n_cols = 2
cols = ['col1', 'col2']

df = pd.DataFrame(np.random.randint(1, 20, size = (n_rows, n_cols)),
                  columns = cols)

df.index = pd.util.testing.makeDateIndex(n_rows, freq = 'H')
df
# Out:
#                      col1  col2
# 2000-01-01 00:00:00     1    14
# 2000-01-01 01:00:00     7    10
# 2000-01-01 02:00:00     9    10
# 2000-01-01 03:00:00     7    10
# 2000-01-01 04:00:00     8    18
# ...                   ...   ...
# 2000-12-30 19:00:00     1    19
# 2000-12-30 20:00:00     3    13
# 2000-12-30 21:00:00     4     9
# 2000-12-30 22:00:00     9     6
# 2000-12-30 23:00:00    15    15
#
# [8760 rows x 2 columns]

# %%
df.resample('M')['col1'].sum().to_frame()
# Out:
#             col1
# 2000-01-31  7280
# 2000-02-29  6854
# 2000-03-31  7419
# 2000-04-30  7363
# 2000-05-31  7329
# 2000-06-30  7158
# 2000-07-31  7300
# 2000-08-31  7311
# 2000-09-30  7307
# 2000-10-31  7319
# 2000-11-30  7098
# 2000-12-31  7285

# %%
df.resample('D')['col1'].sum().to_frame()
# Out:
#             col1
# 2000-01-01   204
# 2000-01-02   239
# 2000-01-03   217
# 2000-01-04   240
# 2000-01-05   168
# ...          ...
# 2000-12-26   300
# 2000-12-27   245
# 2000-12-28   248
# 2000-12-29   226
# 2000-12-30   232
#
# [365 rows x 1 columns]
